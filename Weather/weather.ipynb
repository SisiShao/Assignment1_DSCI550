# %%
import pandas as pd
from meteostat import Point
import matplotlib.pyplot as plt
from datetime import datetime
from meteostat import Point, Daily

# %%
bik = pd.read_csv("sisi_v3.csv",parse_dates = [5])

# %%
latlng = bik["LatLng"].to_list()

# %%
bik["Year"] = bik["Year"].dt.strftime("%Y %-m %-d")

# %%
time_info = bik["Year"].to_list()

# %%
year_list = []
month_list = []
day_list = []
for t in time_info:
    year = int(t.split(" ")[0])
    year_list.append(year)
    month = int(t.split(" ")[1])
    month_list.append(month)
    day = int(t.split(" ")[2])
    day_list.append(day)

# %%
tavg,tmin,tmax,prcp,snow,wdir,wspd,wpgt,pres,tsun = [],[],[],[],[],[],[],[],[],[]

# %%
for (c,i) in enumerate(latlng):
    try:
        lat = float(i.strip().lstrip("(").rstrip(")").split(",")[0])
        lng = float(i.strip().lstrip("(").rstrip(")").split(",")[1])
        pair = (lat,lng)
        location = Point(lat, lng) 
        start = datetime(year_list[c],month_list[c],day_list[c])
        end = datetime(year_list[c],month_list[c],day_list[c])
        data = Daily(location,start,end)
        data = data.fetch()
        avg = float(data["tavg"].to_string().split()[2])
        tavg.append(avg)
        min = float(data["tmin"].to_string().split()[2])
        tmin.append(min)
        max = float(data["tmax"].to_string().split()[2])
        tmax.append(max)
        prcpp = float(data["prcp"].to_string().split()[2])
        prcp.append(prcpp)
        snowp = float(data["snow"].to_string().split()[2])
        snow.append(snowp)
        wdirp = float(data["wdir"].to_string().split()[2])
        wdir.append(wdirp)
        wspdp = float(data["wspd"].to_string().split()[2])
        wspd.append(wspdp)
        wpgtp = float(data["wpgt"].to_string().split()[2])
        wpgt.append(wpgtp)
        presp = float(data["pres"].to_string().split()[2])
        pres.append(presp)
        tsunp = float(data["tsun"].to_string().split()[2])
        tsun.append(tsunp)       
    except:
        tavg.append(" ")
        tmin.append(" ")
        tmax.append(" ")
        prcp.append(" ")
        snow.append(" ")
        wdir.append(" ")
        wspd.append(" ")
        wpgt.append(" ")
        pres.append(" ")
        tsun.append(" ")
# Out:
# Warning: Cannot load daily/40290.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/13015.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/08180.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/08302.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/08301.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/46738.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/03952.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/RKJU0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/11722.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/RKTV0.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/07362.csv.gz from https://bulk.meteostat.net/v2/
# Warning: Cannot load daily/03562.csv.gz from https://bulk.meteostat.net/v2/

# %%
bik["tavg"]=tavg
bik["tmin"]=tmin
bik["tmax"]=tmax
bik["prcp"]=prcp
bik["snow"]=snow
bik["wdir"]=wdir
bik["wspd"]=wspd
bik["wpgt"]=wpgt
bik["pres"]=pres
bik["tsun"]=tsun

# %%
bik.head(100)
# Out:
#     Unnamed: 0                                            Authors  \
# 0            0  Inka Regine Weingaertner, Sarah Koutnik, Herma...
# 1            1  Jessica M. Esparza, Eileen O’Toole, Linya Li, ...
# 2            2  Sreedevi Avasarala, Fangfang Zhang, Guangliang...
# 3            3  Rounak Nassirpour, Pramod P. Mehta, Sangita M....
# 4            4  Jianuo Liu,  Peng Xu, Cory Collins, Han Liu, J...
# ..         ...                                                ...
# 95          95     Chih-Zen Chang, Shu-Chuan Wu, and Aij-Lie Kwan
# 96          96  Jaeson Santos Calla-Choque, Elisa Elvira Figue...
# 97          97  Li Han, Yafeng Wang, Xiaojuan Guo, Yubing Zhou...
# 98          98  Silvana Lorena Della Penna, Gabriel Cao, Andre...
# 99          99  Mao-Lin Ho, Yih-Shou Hsieh, Jia-Yuh Chen, Kuo-...
#
#                                                 Title  \
# 0   Chronic Morphine Treatment Attenuates Cell Gro...
# 1   Katanin Localization Requires Triplet Microtub...
# 2   Curcumin Modulates the Inflammatory Response a...
# 3   miR-221 Promotes Tumorigenesis in Human Triple...
# 4   HIV-1 Tat Protein Increases Microglial Outward...
# ..                                                ...
# 95  Magnesium Lithospermate B, an Active Extract o...
# 96  __-Actinin TvACTN3 of Trichomonas vaginalis Is...
# 97  Downregulation of MDR1 Gene by Cepharanthine H...
# 98  Renal Overexpression of Atrial Natriuretic Pep...
# 99  Antimetastatic Potentials of Dioscorea nipponi...
#
#                                              Citation  \
# 0   PLOS One, January 2013 | Volume 8 | Issue 1 | ...
# 1   PLOS ONE, January 2013 | Volume 8 | Issue 1 | ...
# 2   PLOS ONE, February 2013 | Volume 8 | Issue 2 |...
# 3   PLOS ONE, April 2013 | Volume 8 | Issue 4 | e6...
# 4   PLOS ONE, May 2013 | Volume 8 | Issue 5 | e649...
# ..                                                ...
# 95  BioMed Research International, Volume 2014, Ar...
# 96  BioMed Research International Volume 2014, Art...
# 97  BioMed Research International, Volume 2014, Ar...
# 98  BioMed Research International, Volume 2014, Ar...
# 99  Evidence-Based Complementary, and Alternative ...
#
#                              DOI      Year    0    1    2    3  ...  tavg  \
# 0   10.1371/journal.pone.0053510  2013 1 1  1.0  NaN  1.0  NaN  ...   3.9
# 1   10.1371/journal.pone.0053940  2013 1 1  NaN  1.0  NaN  NaN  ...  -3.9
# 2   10.1371/journal.pone.0057285  2013 1 1  NaN  NaN  1.0  NaN  ...   3.3
# 3   10.1371/journal.pone.0062170  2013 1 1  1.0  NaN  NaN    1  ...   9.7
# 4   10.1371/journal.pone.0064904  2013 1 1  NaN  1.0  NaN  NaN  ...  -9.8
# ..                           ...       ...  ...  ...  ...  ...  ...   ...
# 95           10.1155/2014/272101  2014 1 1  NaN  NaN  1.0  NaN  ...  20.1
# 96           10.1155/2014/424767  2014 1 1  NaN  1.0  NaN  NaN  ...
# 97           10.1155/2014/164391  2014 1 1  NaN  NaN  1.0  NaN  ...
# 98           10.1155/2014/936978  2014 1 1  NaN  1.0  NaN  NaN  ...  27.6
# 99           10.1155/2011/507920  2011 1 1  NaN  NaN  1.0  NaN  ...
#
#     tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# 0   -1.9   8.5   3.2   0.0  227.0  11.2  47.9  1012.6  114.0
# 1   -6.1   0.6   0.0  25.0  355.0  13.5   NaN  1023.4    NaN
# 2   -2.2   4.4   0.0   0.0  285.0  20.5   NaN  1012.3    NaN
# 3    3.3  16.7   0.0   NaN    NaN   7.9   NaN  1020.8    NaN
# 4  -13.8  -6.2   0.0  51.0    NaN   2.8   NaN  1026.3    NaN
# ..   ...   ...   ...   ...    ...   ...   ...     ...    ...
# 95  15.0  27.0   NaN   NaN    NaN   7.6   NaN     NaN    NaN
# 96
# 97
# 98  22.8  32.0   NaN   NaN   20.0  11.0   NaN     NaN    NaN
# 99
#
# [100 rows x 31 columns]

# %%
tiger = pd.read_csv("Tiger_dataset.csv")

# %%
tiger["tavg"]=tavg
tiger["tmin"]=tmin
tiger["tmax"]=tmax
tiger["prcp"]=prcp
tiger["snow"]=snow
tiger["wdir"]=wdir
tiger["wspd"]=wspd
tiger["wpgt"]=wpgt
tiger["pres"]=pres
tiger["tsun"]=tsun

# %%
tiger=tiger.iloc[:,1:]

# %%
tiger
# Out:
#                                                Authors  \
# 0    Inka Regine Weingaertner, Sarah Koutnik, Herma...
# 1    Jessica M. Esparza, Eileen O’Toole, Linya Li, ...
# 2    Sreedevi Avasarala, Fangfang Zhang, Guangliang...
# 3    Rounak Nassirpour, Pramod P. Mehta, Sangita M....
# 4    Jianuo Liu,  Peng Xu, Cory Collins, Han Liu, J...
# ..                                                 ...
# 209  Nathalie Delgehyr, Uta Wieland, He_lène Rangon...
# 210  Rajesh K. Grover, Julong Cheng, Yingjie Peng, ...
# 211  Kevin Y. Lee, Yuji Yamamoto, Jeremie Boucher, ...
# 212  Shuyu Ren, Bryce G. Johnson, Yujiro Kida, Coli...
# 213  Zhongyuan Wang, Yanping Wu, Haifeng Wang, Yang...
#
#                                                  Title  \
# 0    Chronic Morphine Treatment Attenuates Cell Gro...
# 1    Katanin Localization Requires Triplet Microtub...
# 2    Curcumin Modulates the Inflammatory Response a...
# 3    miR-221 Promotes Tumorigenesis in Human Triple...
# 4    HIV-1 Tat Protein Increases Microglial Outward...
# ..                                                 ...
# 209  Drosophila Mgr, a Prefoldin subunit cooperatin...
# 210  The costimulatory immunogen LPS induces the B-...
# 211  Shox2 is a molecular determinant of depot-spec...
# 212  LRP-6 is a coreceptor for multiple fibrogenic ...
# 213  Interplay of mevalonate and Hippo pathways reg...
#
#                                               Citation  \
# 0    PLOS One, January 2013 | Volume 8 | Issue 1 | ...
# 1    PLOS ONE, January 2013 | Volume 8 | Issue 1 | ...
# 2    PLOS ONE, February 2013 | Volume 8 | Issue 2 |...
# 3    PLOS ONE, April 2013 | Volume 8 | Issue 4 | e6...
# 4    PLOS ONE, May 2013 | Volume 8 | Issue 5 | e649...
# ..                                                 ...
# 209  PNAS | April 10, 2012 | vol. 109 | no. 15 | 57...
# 210  PNAS _ April 17, 2012 _ vol. 109 _ no. 16, 603...
# 211  PNAS | July 9, 2013 | vol. 110 | no. 28 | 1140...
# 212      PNAS | January22,2013 | vol.110 | no.4 | 1441
# 213  PNAS | Published online December 23, 2013 | E8...
#
#                               DOI      Year    0    1    2    3  \
# 0    10.1371/journal.pone.0053510  01/01/13  1.0  NaN  1.0  NaN
# 1    10.1371/journal.pone.0053940  01/01/13  NaN  1.0  NaN  NaN
# 2    10.1371/journal.pone.0057285  01/01/13  NaN  NaN  1.0  NaN
# 3    10.1371/journal.pone.0062170  01/01/13  1.0  NaN  NaN    1
# 4    10.1371/journal.pone.0064904  01/01/13  NaN  1.0  NaN  NaN
# ..                            ...       ...  ...  ...  ...  ...
# 209       10.1073/pnas.1108537109  01/01/12  NaN  1.0  NaN  NaN
# 210       10.1073/pnas.1202214109  01/01/12  NaN  1.0  NaN  NaN
# 211       10.1073/pnas.1310331110  01/01/13  NaN  1.0  NaN  NaN
# 212       10.1073/pnas.1211179110  01/01/13  NaN  NaN  1.0  NaN
# 213       10.1073/pnas.1319190110  01/01/14  NaN  NaN  1.0  NaN
#
#                                            FINDINGS  ...  tavg  tmin  tmax  \
# 0               duplicated blot, shifted microscopy  ...   3.9  -1.9   8.5
# 1                           duplicated colony strip  ...  -3.9  -6.1   0.6
# 2    reuse of one lane in different blot experiment  ...   3.3  -2.2   4.4
# 3               Duplicated / mirrored bands in blot  ...   9.7   3.3  16.7
# 4             multiple duplicated microscopy images  ...  -9.8 -13.8  -6.2
# ..                                              ...  ...   ...   ...   ...
# 209                                             NaN  ...  11.0   8.0  12.0
# 210                                             NaN  ...  14.7   6.1  27.2
# 211                                             NaN  ...  -0.1  -6.7   2.8
# 212                                             NaN  ...   1.8  -1.7   6.1
# 213                                             NaN  ...  -7.7 -13.8  -0.4
#
#      prcp   snow   wdir  wspd  wpgt    pres   tsun
# 0     3.2    0.0  227.0  11.2  47.9  1012.6  114.0
# 1     0.0   25.0  355.0  13.5   NaN  1023.4    NaN
# 2     0.0    0.0  285.0  20.5   NaN  1012.3    NaN
# 3     0.0    NaN    NaN   7.9   NaN  1020.8    NaN
# 4     0.0   51.0    NaN   2.8   NaN  1026.3    NaN
# ..    ...    ...    ...   ...   ...     ...    ...
# 209   NaN    NaN  222.0  20.6   NaN  1001.7    NaN
# 210   0.0    NaN    NaN   6.1   NaN  1019.6    NaN
# 211   0.0  102.0  274.0  23.0   NaN  1008.6  313.0
# 212   0.0    0.0   34.0   1.8   NaN  1030.8    NaN
# 213   NaN    NaN    NaN   NaN   NaN     NaN    NaN
#
# [214 rows x 38 columns]

# %%
tiger.to_csv("sisi_v4.csv",index=False)
